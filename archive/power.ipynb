# %% [markdown]
# ### Imports

# %%
# %load_ext google.cloud.bigquery
# %matplotlib inline
from google.cloud import bigquery
client = bigquery.Client()
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import cluster
from sklearn.metrics import silhouette_score, silhouette_samples
from sklearn.preprocessing import StandardScaler, PowerTransformer, FunctionTransformer
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
import random
from sklearn.cluster import KMeans
import matplotlib.cm as cm
# %run silhouette_plotter.py
# %run parse.py
from mpl_toolkits.mplot3d import Axes3D
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %% [markdown]
# ### Load data from Bigquery

# %%
table = 'eth-tokens.test.clean_avg_1MM_with_balances_tokens'
label_table = 'eth-tokens.alldata.etherscan_labelcloud'

# %%
sql = '''
SELECT *  FROM `{}`
'''.format(table)

df = client.query(sql).to_dataframe()

# %%
#remove address (string) from analysis
data = df.iloc[:,1:]

# %%
#number of PCA features is full reconstruction, for now
num_features = data.shape[1]
num_clusters = 4
num_features = 15

# %%
pwr = PowerTransformer(standardize=False)
scale = StandardScaler()
pca =PCA(n_components=num_features)
cl = KMeans(num_clusters)

#build pipeline
pipe = Pipeline([('power', pwr ),
                 ('scale', scale ),
                 ('PCA', pca)])

results = pipe.fit_transform(data)

# %%
#percent of variance explained by each component

plt.plot(np.arange(pca.n_components_) ,np.cumsum(pca.explained_variance_ratio_)*100)
plt.grid(b=True)
plt.xlabel('principal component')
plt.title('Cumulative Percent of Variance explained')
plt.show()

# %% [markdown]
# ### Choose number of clusters with Calinski-Harabaz, Elbow Plot

# %%
# #scoring metric?
# from sklearn.metrics import calinski_harabaz_score as ch_score
# clusters = [3,5,8,10,15,20,30,40,60,80]
# scores = []
# inertias = []
# for c in clusters:
#     cl_n = KMeans(c).fit(results)
#     score = ch_score(results, cl_n.labels_)
#     scores.append(score)
#     inertias.append(cl_n.inertia_)


# plt.plot(clusters, scores)
# plt.title('Calinski Harabaz Scores')

# %%
# #elbow plot
# plt.plot(clusters,inertias)
# plt.title('Elbow plot')
# plt.ylabel('within cluster sum of squares')

# %% [markdown]
# ## Optimal clusters

# %%
#optimal number of clusters is around 40
cl = KMeans(15)
cl.fit(results)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=15, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
# %run silhouette_plotter.py
# X=results
# range_n_clusters = [20]
# if len(newresults) <20000:
#     silhouette_plotter(X, range_n_clusters)

# %%
#subset results for tsne
#address mask needed for later superposition
max_size = len(results)
subset_results = []
lbls = []
address_mask = np.array([False for addr in df['address']]) 
for c in np.unique(cl.labels_):
    mask = (cl.labels_==c)
    c_size = np.sum(mask)
    if c_size < max_size:
        lbls.extend(list(cl.labels_[cl.labels_==c]))
        subset_results.append(results[mask])
        address_mask |= mask
lbls=np.array(lbls)
subset_results=np.vstack(subset_results)

# %%
#not using subset
subset_results = results
lbls = cl.labels_

# %%
import time
from sklearn.manifold import TSNE

time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=500)
tsne_results = tsne.fit_transform(subset_results)

print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 239630 samples in 0.315s...
# [t-SNE] Computed neighbors for 239630 samples in 203.493s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 239630
# [t-SNE] Computed conditional probabilities for sample 2000 / 239630
# [t-SNE] Computed conditional probabilities for sample 3000 / 239630
# [t-SNE] Computed conditional probabilities for sample 4000 / 239630
# [t-SNE] Computed conditional probabilities for sample 5000 / 239630
# [t-SNE] Computed conditional probabilities for sample 6000 / 239630
# [t-SNE] Computed conditional probabilities for sample 7000 / 239630
# [t-SNE] Computed conditional probabilities for sample 8000 / 239630
# [t-SNE] Computed conditional probabilities for sample 9000 / 239630
# [t-SNE] Computed conditional probabilities for sample 10000 / 239630
# [t-SNE] Computed conditional probabilities for sample 11000 / 239630
# [t-SNE] Computed conditional probabilities for sample 12000 / 239630
# [t-SNE] Computed conditional probabilities for sample 13000 / 239630
# [t-SNE] Computed conditional probabilities for sample 14000 / 239630
# [t-SNE] Computed conditional probabilities for sample 15000 / 239630
# [t-SNE] Computed conditional probabilities for sample 16000 / 239630
# [t-SNE] Computed conditional probabilities for sample 17000 / 239630
# [t-SNE] Computed conditional probabilities for sample 18000 / 239630
# [t-SNE] Computed conditional probabilities for sample 19000 / 239630
# [t-SNE] Computed conditional probabilities for sample 20000 / 239630
# [t-SNE] Computed conditional probabilities for sample 21000 / 239630
# [t-SNE] Computed conditional probabilities for sample 22000 / 239630
# [t-SNE] Computed conditional probabilities for sample 23000 / 239630
# [t-SNE] Computed conditional probabilities for sample 24000 / 239630
# [t-SNE] Computed conditional probabilities for sample 25000 / 239630
# [t-SNE] Computed conditional probabilities for sample 26000 / 239630
# [t-SNE] Computed conditional probabilities for sample 27000 / 239630
# [t-SNE] Computed conditional probabilities for sample 28000 / 239630
# [t-SNE] Computed conditional probabilities for sample 29000 / 239630
# [t-SNE] Computed conditional probabilities for sample 30000 / 239630
# [t-SNE] Computed conditional probabilities for sample 31000 / 239630
# [t-SNE] Computed conditional probabilities for sample 32000 / 239630
# [t-SNE] Computed conditional probabilities for sample 33000 / 239630
# [t-SNE] Computed conditional probabilities for sample 34000 / 239630
# [t-SNE] Computed conditional probabilities for sample 35000 / 239630
# [t-SNE] Computed conditional probabilities for sample 36000 / 239630
# [t-SNE] Computed conditional probabilities for sample 37000 / 239630
# [t-SNE] Computed conditional probabilities for sample 38000 / 239630
# [t-SNE] Computed conditional probabilities for sample 39000 / 239630
# [t-SNE] Computed conditional probabilities for sample 40000 / 239630
# [t-SNE] Computed conditional probabilities for sample 41000 / 239630
# [t-SNE] Computed conditional probabilities for sample 42000 / 239630
# [t-SNE] Computed conditional probabilities for sample 43000 / 239630
# [t-SNE] Computed conditional probabilities for sample 44000 / 239630
# [t-SNE] Computed conditional probabilities for sample 45000 / 239630
# [t-SNE] Computed conditional probabilities for sample 46000 / 239630
# [t-SNE] Computed conditional probabilities for sample 47000 / 239630
# [t-SNE] Computed conditional probabilities for sample 48000 / 239630
# [t-SNE] Computed conditional probabilities for sample 49000 / 239630
# [t-SNE] Computed conditional probabilities for sample 50000 / 239630
# [t-SNE] Computed conditional probabilities for sample 51000 / 239630
# [t-SNE] Computed conditional probabilities for sample 52000 / 239630
# [t-SNE] Computed conditional probabilities for sample 53000 / 239630
# [t-SNE] Computed conditional probabilities for sample 54000 / 239630
# [t-SNE] Computed conditional probabilities for sample 55000 / 239630
# [t-SNE] Computed conditional probabilities for sample 56000 / 239630
# [t-SNE] Computed conditional probabilities for sample 57000 / 239630
# [t-SNE] Computed conditional probabilities for sample 58000 / 239630
# [t-SNE] Computed conditional probabilities for sample 59000 / 239630
# [t-SNE] Computed conditional probabilities for sample 60000 / 239630
# [t-SNE] Computed conditional probabilities for sample 61000 / 239630
# [t-SNE] Computed conditional probabilities for sample 62000 / 239630
# [t-SNE] Computed conditional probabilities for sample 63000 / 239630
# [t-SNE] Computed conditional probabilities for sample 64000 / 239630
# [t-SNE] Computed conditional probabilities for sample 65000 / 239630
# [t-SNE] Computed conditional probabilities for sample 66000 / 239630
# [t-SNE] Computed conditional probabilities for sample 67000 / 239630
# [t-SNE] Computed conditional probabilities for sample 68000 / 239630
# [t-SNE] Computed conditional probabilities for sample 69000 / 239630
# [t-SNE] Computed conditional probabilities for sample 70000 / 239630
# [t-SNE] Computed conditional probabilities for sample 71000 / 239630
# [t-SNE] Computed conditional probabilities for sample 72000 / 239630
# [t-SNE] Computed conditional probabilities for sample 73000 / 239630
# [t-SNE] Computed conditional probabilities for sample 74000 / 239630
# [t-SNE] Computed conditional probabilities for sample 75000 / 239630
# [t-SNE] Computed conditional probabilities for sample 76000 / 239630
# [t-SNE] Computed conditional probabilities for sample 77000 / 239630
# [t-SNE] Computed conditional probabilities for sample 78000 / 239630
# [t-SNE] Computed conditional probabilities for sample 79000 / 239630
# [t-SNE] Computed conditional probabilities for sample 80000 / 239630
# [t-SNE] Computed conditional probabilities for sample 81000 / 239630
# [t-SNE] Computed conditional probabilities for sample 82000 / 239630
# [t-SNE] Computed conditional probabilities for sample 83000 / 239630
# [t-SNE] Computed conditional probabilities for sample 84000 / 239630
# [t-SNE] Computed conditional probabilities for sample 85000 / 239630
# [t-SNE] Computed conditional probabilities for sample 86000 / 239630
# [t-SNE] Computed conditional probabilities for sample 87000 / 239630
# [t-SNE] Computed conditional probabilities for sample 88000 / 239630
# [t-SNE] Computed conditional probabilities for sample 89000 / 239630
# [t-SNE] Computed conditional probabilities for sample 90000 / 239630
# [t-SNE] Computed conditional probabilities for sample 91000 / 239630
# [t-SNE] Computed conditional probabilities for sample 92000 / 239630
# [t-SNE] Computed conditional probabilities for sample 93000 / 239630
# [t-SNE] Computed conditional probabilities for sample 94000 / 239630
# [t-SNE] Computed conditional probabilities for sample 95000 / 239630
# [t-SNE] Computed conditional probabilities for sample 96000 / 239630
# [t-SNE] Computed conditional probabilities for sample 97000 / 239630
# [t-SNE] Computed conditional probabilities for sample 98000 / 239630
# [t-SNE] Computed conditional probabilities for sample 99000 / 239630
# [t-SNE] Computed conditional probabilities for sample 100000 / 239630
# [t-SNE] Computed conditional probabilities for sample 101000 / 239630
# [t-SNE] Computed conditional probabilities for sample 102000 / 239630
# [t-SNE] Computed conditional probabilities for sample 103000 / 239630
# [t-SNE] Computed conditional probabilities for sample 104000 / 239630
# [t-SNE] Computed conditional probabilities for sample 105000 / 239630
# [t-SNE] Computed conditional probabilities for sample 106000 / 239630
# [t-SNE] Computed conditional probabilities for sample 107000 / 239630
# [t-SNE] Computed conditional probabilities for sample 108000 / 239630
# [t-SNE] Computed conditional probabilities for sample 109000 / 239630
# [t-SNE] Computed conditional probabilities for sample 110000 / 239630
# [t-SNE] Computed conditional probabilities for sample 111000 / 239630
# [t-SNE] Computed conditional probabilities for sample 112000 / 239630
# [t-SNE] Computed conditional probabilities for sample 113000 / 239630
# [t-SNE] Computed conditional probabilities for sample 114000 / 239630
# [t-SNE] Computed conditional probabilities for sample 115000 / 239630
# [t-SNE] Computed conditional probabilities for sample 116000 / 239630
# [t-SNE] Computed conditional probabilities for sample 117000 / 239630
# [t-SNE] Computed conditional probabilities for sample 118000 / 239630
# [t-SNE] Computed conditional probabilities for sample 119000 / 239630
# [t-SNE] Computed conditional probabilities for sample 120000 / 239630
# [t-SNE] Computed conditional probabilities for sample 121000 / 239630
# [t-SNE] Computed conditional probabilities for sample 122000 / 239630
# [t-SNE] Computed conditional probabilities for sample 123000 / 239630
# [t-SNE] Computed conditional probabilities for sample 124000 / 239630
# [t-SNE] Computed conditional probabilities for sample 125000 / 239630
# [t-SNE] Computed conditional probabilities for sample 126000 / 239630
# [t-SNE] Computed conditional probabilities for sample 127000 / 239630
# [t-SNE] Computed conditional probabilities for sample 128000 / 239630
# [t-SNE] Computed conditional probabilities for sample 129000 / 239630
# [t-SNE] Computed conditional probabilities for sample 130000 / 239630
# [t-SNE] Computed conditional probabilities for sample 131000 / 239630
# [t-SNE] Computed conditional probabilities for sample 132000 / 239630
# [t-SNE] Computed conditional probabilities for sample 133000 / 239630
# [t-SNE] Computed conditional probabilities for sample 134000 / 239630
# [t-SNE] Computed conditional probabilities for sample 135000 / 239630
# [t-SNE] Computed conditional probabilities for sample 136000 / 239630
# [t-SNE] Computed conditional probabilities for sample 137000 / 239630
# [t-SNE] Computed conditional probabilities for sample 138000 / 239630
# [t-SNE] Computed conditional probabilities for sample 139000 / 239630
# [t-SNE] Computed conditional probabilities for sample 140000 / 239630
# [t-SNE] Computed conditional probabilities for sample 141000 / 239630
# [t-SNE] Computed conditional probabilities for sample 142000 / 239630
# [t-SNE] Computed conditional probabilities for sample 143000 / 239630
# [t-SNE] Computed conditional probabilities for sample 144000 / 239630
# [t-SNE] Computed conditional probabilities for sample 145000 / 239630
# [t-SNE] Computed conditional probabilities for sample 146000 / 239630
# [t-SNE] Computed conditional probabilities for sample 147000 / 239630
# [t-SNE] Computed conditional probabilities for sample 148000 / 239630
# [t-SNE] Computed conditional probabilities for sample 149000 / 239630
# [t-SNE] Computed conditional probabilities for sample 150000 / 239630
# [t-SNE] Computed conditional probabilities for sample 151000 / 239630
# [t-SNE] Computed conditional probabilities for sample 152000 / 239630
# [t-SNE] Computed conditional probabilities for sample 153000 / 239630
# [t-SNE] Computed conditional probabilities for sample 154000 / 239630
# [t-SNE] Computed conditional probabilities for sample 155000 / 239630
# [t-SNE] Computed conditional probabilities for sample 156000 / 239630
# [t-SNE] Computed conditional probabilities for sample 157000 / 239630
# [t-SNE] Computed conditional probabilities for sample 158000 / 239630
# [t-SNE] Computed conditional probabilities for sample 159000 / 239630
# [t-SNE] Computed conditional probabilities for sample 160000 / 239630
# [t-SNE] Computed conditional probabilities for sample 161000 / 239630
# [t-SNE] Computed conditional probabilities for sample 162000 / 239630
# [t-SNE] Computed conditional probabilities for sample 163000 / 239630
# [t-SNE] Computed conditional probabilities for sample 164000 / 239630
# [t-SNE] Computed conditional probabilities for sample 165000 / 239630
# [t-SNE] Computed conditional probabilities for sample 166000 / 239630
# [t-SNE] Computed conditional probabilities for sample 167000 / 239630
# [t-SNE] Computed conditional probabilities for sample 168000 / 239630
# [t-SNE] Computed conditional probabilities for sample 169000 / 239630
# [t-SNE] Computed conditional probabilities for sample 170000 / 239630
# [t-SNE] Computed conditional probabilities for sample 171000 / 239630
# [t-SNE] Computed conditional probabilities for sample 172000 / 239630
# [t-SNE] Computed conditional probabilities for sample 173000 / 239630
# [t-SNE] Computed conditional probabilities for sample 174000 / 239630
# [t-SNE] Computed conditional probabilities for sample 175000 / 239630
# [t-SNE] Computed conditional probabilities for sample 176000 / 239630
# [t-SNE] Computed conditional probabilities for sample 177000 / 239630
# [t-SNE] Computed conditional probabilities for sample 178000 / 239630
# [t-SNE] Computed conditional probabilities for sample 179000 / 239630
# [t-SNE] Computed conditional probabilities for sample 180000 / 239630
# [t-SNE] Computed conditional probabilities for sample 181000 / 239630
# [t-SNE] Computed conditional probabilities for sample 182000 / 239630
# [t-SNE] Computed conditional probabilities for sample 183000 / 239630
# [t-SNE] Computed conditional probabilities for sample 184000 / 239630
# [t-SNE] Computed conditional probabilities for sample 185000 / 239630
# [t-SNE] Computed conditional probabilities for sample 186000 / 239630
# [t-SNE] Computed conditional probabilities for sample 187000 / 239630
# [t-SNE] Computed conditional probabilities for sample 188000 / 239630
# [t-SNE] Computed conditional probabilities for sample 189000 / 239630
# [t-SNE] Computed conditional probabilities for sample 190000 / 239630
# [t-SNE] Computed conditional probabilities for sample 191000 / 239630
# [t-SNE] Computed conditional probabilities for sample 192000 / 239630
# [t-SNE] Computed conditional probabilities for sample 193000 / 239630
# [t-SNE] Computed conditional probabilities for sample 194000 / 239630
# [t-SNE] Computed conditional probabilities for sample 195000 / 239630
# [t-SNE] Computed conditional probabilities for sample 196000 / 239630
# [t-SNE] Computed conditional probabilities for sample 197000 / 239630
# [t-SNE] Computed conditional probabilities for sample 198000 / 239630
# [t-SNE] Computed conditional probabilities for sample 199000 / 239630
# [t-SNE] Computed conditional probabilities for sample 200000 / 239630
# [t-SNE] Computed conditional probabilities for sample 201000 / 239630
# [t-SNE] Computed conditional probabilities for sample 202000 / 239630
# [t-SNE] Computed conditional probabilities for sample 203000 / 239630
# [t-SNE] Computed conditional probabilities for sample 204000 / 239630
# [t-SNE] Computed conditional probabilities for sample 205000 / 239630
# [t-SNE] Computed conditional probabilities for sample 206000 / 239630
# [t-SNE] Computed conditional probabilities for sample 207000 / 239630
# [t-SNE] Computed conditional probabilities for sample 208000 / 239630
# [t-SNE] Computed conditional probabilities for sample 209000 / 239630
# [t-SNE] Computed conditional probabilities for sample 210000 / 239630
# [t-SNE] Computed conditional probabilities for sample 211000 / 239630
# [t-SNE] Computed conditional probabilities for sample 212000 / 239630
# [t-SNE] Computed conditional probabilities for sample 213000 / 239630
# [t-SNE] Computed conditional probabilities for sample 214000 / 239630
# [t-SNE] Computed conditional probabilities for sample 215000 / 239630
# [t-SNE] Computed conditional probabilities for sample 216000 / 239630
# [t-SNE] Computed conditional probabilities for sample 217000 / 239630
# [t-SNE] Computed conditional probabilities for sample 218000 / 239630
# [t-SNE] Computed conditional probabilities for sample 219000 / 239630
# [t-SNE] Computed conditional probabilities for sample 220000 / 239630
# [t-SNE] Computed conditional probabilities for sample 221000 / 239630
# [t-SNE] Computed conditional probabilities for sample 222000 / 239630
# [t-SNE] Computed conditional probabilities for sample 223000 / 239630
# [t-SNE] Computed conditional probabilities for sample 224000 / 239630
# [t-SNE] Computed conditional probabilities for sample 225000 / 239630
# [t-SNE] Computed conditional probabilities for sample 226000 / 239630
# [t-SNE] Computed conditional probabilities for sample 227000 / 239630
# [t-SNE] Computed conditional probabilities for sample 228000 / 239630
# [t-SNE] Computed conditional probabilities for sample 229000 / 239630
# [t-SNE] Computed conditional probabilities for sample 230000 / 239630
# [t-SNE] Computed conditional probabilities for sample 231000 / 239630
# [t-SNE] Computed conditional probabilities for sample 232000 / 239630
# [t-SNE] Computed conditional probabilities for sample 233000 / 239630
# [t-SNE] Computed conditional probabilities for sample 234000 / 239630
# [t-SNE] Computed conditional probabilities for sample 235000 / 239630
# [t-SNE] Computed conditional probabilities for sample 236000 / 239630
# [t-SNE] Computed conditional probabilities for sample 237000 / 239630
# [t-SNE] Computed conditional probabilities for sample 238000 / 239630
# [t-SNE] Computed conditional probabilities for sample 239000 / 239630
# [t-SNE] Computed conditional probabilities for sample 239630 / 239630
# [t-SNE] Mean sigma: 0.491450
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 117.423470
# [t-SNE] KL divergence after 500 iterations: 4.841956
# t-SNE done! Time elapsed: 2244.203617811203 seconds

# %%
#color coded by cluster
plt.figure(figsize=(12,8))

plt.scatter(tsne_results[:,0], tsne_results[:,1], s=10,c=lbls,cmap='tab20b', alpha=.4)


# leg = plt.legend()




# for lh in leg.legendHandles: 
#     lh.set_alpha(1)
plt.title('T-SNE')
plt.xlabel('first principal component')
plt.ylabel('second principal component')
plt.show()

# %%
plt.figure(figsize=(12,10))
for c in np.unique(lbls):
    mask = lbls==c
    if np.sum(mask) <0:
        lbl = '_nolegend_'
    else:
        lbl = c
    plt.scatter(tsne_results[mask][:,0], tsne_results[mask][:,1], s=15,alpha=.1,label=lbl)
leg = plt.legend()
for lh in leg.legendHandles: 
    lh.set_alpha(1)
plt.title('T-SNE')
plt.xlabel('first principal component')
plt.ylabel('second principal component')
plt.tight_layout()

# %%
plt.scatter(results[:,0],results[:,1],c=cl.labels_)
# plt.xlim(-10,100)
# plt.ylim(-15,10)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(results[:,0],results[:,1],results[:,2],c=cl.labels_)

# ax.set_xlim3d(-10,10)
# ax.set_ylim3d(-15,10)

# %% [markdown]
# ## Label centroids with cluster

# %%
c = cl.cluster_centers_
#transform back to real numbers
centroids = pwr.inverse_transform(scale.inverse_transform(pca.inverse_transform(c)))
df_summary = pd.DataFrame(centroids, columns = data.columns)

# %%
#put cluster sizes into summary dataframe
cluster_sizes = pd.Series(cl.labels_).value_counts()
df_summary['cluster_size'] = cluster_sizes

# %%
df_summary.sort_values('cluster_size', ascending=False, axis=0, inplace=True)
df_summary
# Out:
#     outgoing_txns  incoming_txns  total_eth_sent  avg_eth_sent  \
# 7        6.271974       7.839710        8.155294      1.547572
# 0        7.083308      57.235808        4.425696      0.654123
# 2        5.547701       7.885650        3.863907      0.854050
# 10       6.438276       8.023146       23.008350      4.166505
# 1       21.874951      21.007509       41.652939      2.427322
# 8        5.575716       8.494765        1.407043      0.287358
# 3        8.017035      10.062605       65.382727      9.404181
# 9        9.751628      10.890245      278.507988     26.914964
# 4       10.550892     211.089286       35.738896      3.951868
# 6       60.568233      91.074644      673.372729     13.775705
# 14      49.641189     114.608561       29.262717      0.592721
# 13      16.275672      18.798555     4508.098168    188.776871
# 11      20.205955      18.958185       50.076535      4.107339
# 12    2655.556758    1026.859152    15407.155570     11.254587
# 5       50.442874      22.254255       63.531276      2.610507
#
#     total_usd_sent  avg_usd_sent  total_eth_recd  avg_eth_recd  \
# 7     4.888817e+03    795.849852       13.951523      2.276633
# 0     1.798893e+03    261.233266        9.951986      0.082021
# 2     1.340366e+03    253.579151        8.014864      1.306208
# 10    1.220025e+04   1896.881665       44.926538      6.759847
# 1     2.553505e+04   1204.707910       57.104394      3.289549
# 8     3.137462e+02     63.536865        4.632933      0.685724
# 3     3.361705e+04   4317.085604       94.331680     10.872650
# 9     1.140004e+05  11841.747538      473.929715     38.753653
# 4     1.836766e+04   1731.046818       60.747088      0.489312
# 6     3.073255e+05   5164.918637      688.162619      9.727848
# 14    1.280741e+04    268.071512       38.019442      0.460251
# 13    1.274268e+06  82040.983403     5955.396103    190.088955
# 11    1.244184e+04    707.133454       66.347096      5.044152
# 12    4.540964e+06   1608.004963    12853.541462     17.613780
# 5     1.153355e+04    287.544895       68.411848      4.150536
#
#     total_usd_recd  avg_usd_recd      ...       monthly_usd_recd  \
# 7     8.192294e+03   1063.627565      ...             772.169200
# 0     3.690621e+03     66.738597      ...             296.494523
# 2     3.090914e+03    398.673657      ...             222.336834
# 10    1.771016e+04   2239.718481      ...            1150.422856
# 1     3.219792e+04   1585.680299      ...            2156.884981
# 8     1.655945e+03    202.275115      ...             158.456567
# 3     4.851429e+04   4969.131069      ...            5730.016556
# 9     1.180390e+05  11228.332539      ...            7138.576179
# 4     2.704156e+04    124.926888      ...            1823.742440
# 6     3.510556e+05   3850.726203      ...           28419.910263
# 14    1.542148e+04    136.092292      ...            1491.911175
# 13    1.441036e+06  80154.931081      ...          125134.006577
# 11    1.735289e+04    969.686950      ...            1217.015624
# 12    3.836960e+06   3419.921060      ...          462811.266568
# 5     1.629489e+04    779.341785      ...            1360.872295
#
#     contracts_created  contract_txns_sent  incoming_avg_time_btwn_txns  \
# 7            0.000927            0.001841                 1.078302e+06
# 0            0.001807            0.003058                 4.112706e+05
# 2            0.003659            0.008444                 2.890626e+06
# 10           0.002524            0.004706                 2.797741e+06
# 1            0.000510            0.000199                 1.105854e+06
# 8            0.004297            0.009691                 1.112515e+06
# 3            0.001105            0.001773                 6.755928e+05
# 9            0.004846            0.010709                 1.880226e+06
# 4            0.004253            0.007025                 1.626649e+05
# 6            0.001876            0.004561                 2.832294e+05
# 14           0.000827            0.001328                 1.947312e+05
# 13           0.009394            0.033261                 7.184302e+05
# 11           2.245639           66.394643                 1.201320e+06
# 12           0.027049            0.169034                 2.843666e+04
# 5           32.816894          534.049103                 9.488633e+05
#
#     incoming_std_time_btwn_txns  outgoing_avg_time_btwn_txns  \
# 7                  1.338935e+06                 7.785252e+05
# 0                  2.698162e+05                 2.161400e+06
# 2                  3.626422e+06                 3.748858e+06
# 10                 3.856908e+06                 3.391776e+06
# 1                  1.744296e+06                 8.997647e+05
# 8                  1.212485e+06                 4.385292e+05
# 3                  9.526400e+05                 7.539912e+05
# 9                  2.953262e+06                 2.193054e+06
# 4                  1.621374e+05                 2.046738e+06
# 6                  6.062595e+05                 4.039207e+05
# 14                 1.895562e+05                 3.762002e+05
# 13                 1.246264e+06                 9.617654e+05
# 11                 1.900722e+06                 1.047730e+06
# 12                 1.334764e+05                 3.685873e+04
# 5                  1.574496e+06                 4.913045e+05
#
#     outgoing_std_time_btwn_txns  num_tokens_used  eth_balance  cluster_size
# 7                  8.522283e+05         6.085029     4.323425         32969
# 0                  2.239010e+06         5.142457     3.483143         32040
# 2                  4.412806e+06         8.269422     3.125621         30613
# 10                 4.252392e+06        10.752211    10.982634         27074
# 1                  1.621050e+06        21.081299     5.772408         19769
# 8                  4.468394e+05         5.333596     2.555178         17350
# 3                  9.381946e+05         4.671574    11.572707         16247
# 9                  3.297187e+06        14.699058    52.660725         16233
# 4                  2.370608e+06         9.352674    13.323622         15299
# 6                  7.769647e+05        17.993983    13.810675         10802
# 14                 5.478666e+05         5.297058     4.126079          9495
# 13                 1.611571e+06        12.684288   147.433282          7473
# 11                 1.740358e+06        12.858122     7.845629          2169
# 12                 3.751183e+04        16.858105    77.894144          1546
# 5                  9.608466e+05        11.935345     8.697269           551
#
# [15 rows x 26 columns]

# %%
import seaborn as sns
sns.heatmap(df_summary.corr())

# %%
arr = df_summary.values

# %%
sns.heatmap(np.corrcoef(arr, rowvar=True))

# %% [markdown]
# ## Review Etherscan Labels

# %%
sql = '''
SELECT es.label,es.category, a.*  FROM `{}` a
INNER JOIN `{}` es
ON a.address = es.address
WHERE es.label IS NOT NULL

'''.format(table, label_table)

dflabel = client.query(sql).to_dataframe()

# %%
lbls = []
for i, row in dflabel.iterrows():
    lbls.append(list(df['address'].values).index(row['address']))

# %%
dflabel['cluster'] = [cl.labels_[i] for i in lbls]

# %%
# for clust in range(cl.n_clusters):
#     print('cluster {}'.format(clust))
#     print('labelled points: {}'.format(np.sum([dflabel['cluster']==clust])))
#     print('total points: {}'.format(np.sum(cl.labels_==clust)))
#     print(dflabel[dflabel['cluster']==clust][['label','category']])
#     print('\n\n\n')

# %% [markdown]
# centralization of ownership

# %%
total_eth = {}
total_addresses = {}

for clust in range(cl.n_clusters):
    mask = cl.labels_==clust
    eth = np.sum(df[mask]['eth_balance'])
    size = np.sum(cl.labels_==clust)
    total_eth[clust] = eth
    total_addresses[clust] = size

# %%
plt.pie(total_eth.values(), labels=total_eth.keys())
plt.title('Centralization of Ownership by Cluster')
plt.show()

# %%
plt.pie(total_addresses.values(), labels=total_addresses.keys())
plt.title('Addresses per cluster')
plt.show()

# %%
names = np.array(list(total_eth.keys()))
values = np.array(list(total_eth.values()))
indices = np.argsort(values)

names = names[indices][::-1]
values = values[indices][::-1]
                  
#tick_label does the some work as plt.xticks()
plt.figure(figsize=(12,8))
plt.bar(range(len(total_eth)),values/sum(values)*100,tick_label=names)
plt.title('Total Value by Cluster')
plt.xlabel('cluster number')
plt.ylabel('% of total value')
# plt.yscale('log')
plt.tight_layout()
plt.show()

# %%
names = np.array(list(total_addresses.keys()))
values = np.array(list(total_addresses.values()))

names = names[indices][::-1]
values = values[indices][::-1]
                  
#tick_label does the some work as plt.xticks()
plt.figure(figsize=(12,8))
plt.bar(range(len(total_addresses)),values/sum(values)*100,tick_label=names)
plt.title('Addresses per Cluster')
plt.yscale('log')
plt.xlabel('cluster number')
plt.ylabel('% of total addressses')
plt.show()

# %%
# for clust in range(cl.n_clusters):
#     cluster_data = df[cl.labels_==clust]
#     print('cluster {}'.format(clust))
#     logbins = np.logspace(0,8,16)
#     plt.hist(cluster_data['incoming_avg_time_btwn_txns'], bins=logbins)
#     plt.xscale('log')
#     plt.show()

# %%
labelresults = pipe.fit_transform(dflabel.iloc[:,3:-1])

# %%
labelcl = KMeans(15).fit(labelresults)
dflabel['cluster'] = [labelcl.labels_[i] for i in range(len(dflabel))]

# %%
time_start = time.time()
tsne_label = TSNE(n_components=2, verbose=1, perplexity=20, n_iter=20000)
tsne_results_label = tsne_label.fit_transform(labelresults)

print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 182 samples in 0.000s...
# [t-SNE] Computed neighbors for 182 samples in 0.003s...
# [t-SNE] Computed conditional probabilities for sample 182 / 182
# [t-SNE] Mean sigma: 1.921014
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 60.692711
# [t-SNE] KL divergence after 1850 iterations: 0.364558
# t-SNE done! Time elapsed: 1.1584007740020752 seconds

# %%
plt.figure(figsize=(12,8))
for c in np.unique(labelcl.labels_):
    mask = labelcl.labels_==c
    if np.sum(mask) <1:
        lbl = '_nolegend_'
    else:
        lbl = c
    plt.scatter(tsne_results_label[mask][:,0], tsne_results_label[mask][:,1], alpha=1,label=lbl)
leg = plt.legend()
for lh in leg.legendHandles: 
    lh.set_alpha(1)
plt.title('T-SNE')
plt.xlabel('first principal component')
plt.ylabel('second principal component')
plt.show()

# %%
plt.figure(figsize=(12,8))

for c in np.unique(dflabel['category']):
    mask = dflabel['category']==c
    if np.sum(mask) <1:
        lbl = '_nolegend_'
    else:
        lbl = c
    plt.scatter(tsne_results_label[mask][:,0], tsne_results_label[mask][:,1], alpha=1,label=lbl)
leg = plt.legend()
for lh in leg.legendHandles: 
    lh.set_alpha(1)
plt.title('T-SNE')
plt.xlabel('first principal component')
plt.ylabel('second principal component')
plt.show()

# %% [markdown]
# ## subset original T-SNE results
# create a mask for all points that are labelled

# %%
labeled_addresses = dflabel['address'].values
labelmask = np.array([addr in labeled_addresses for addr in df['address'] ] )

# #labelmask for subset results!!!
# labelmask = np.array([addr in labeled_addresses for addr in df['address'][address_mask]] )

# %%
#helper function for category mask
def cat(addr, labeled_addresses, dflabel):
    if addr not in labeled_addresses:
        return False
    else:
        idx = int(np.where(labeled_addresses==addr)[0][0])
        return dflabel['category'][idx]

# %%
#setting up color map
NUM_COLORS = len(dflabel['category'].unique())
cm = plt.get_cmap('tab20')

# %%
subset, not_subset  = tsne_results[labelmask] , tsne_results[~labelmask]
fig = plt.figure(figsize=(12,8))
#not labelled points
plt.scatter(not_subset[:,0], not_subset[:,1], c='gray', alpha=.005)

#categories
cats = np.array([cat(addr, labeled_addresses, dflabel) for addr in df['address']])#[address_mask] ]) #added address mask for all clusters

#labelled points

# ax = fig.add_subplot(111)
# ax.set_color_cycle([cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])

for c in list(dflabel['category'].unique()):
    mask = dflabel['category']==c
    if np.sum(mask) <1:
        lbl = '_nolegend_'
    else:
        lbl = c
    
    #category mask
    catmask = cats == c
    if np.sum(mask) >5:
        plt.scatter(tsne_results[(labelmask & catmask)][:,0], tsne_results[(labelmask & catmask)][:,1], alpha=1,label=lbl)

leg = plt.legend(bbox_to_anchor=(1, 1))
for lh in leg.legendHandles: 
    lh.set_alpha(1)

plt.title('T-SNE')
plt.xlabel('first principal component')
plt.ylabel('second principal component')
plt.show()

# %%
for clust in range(cl.n_clusters):
    print('cluster {}'.format(clust))
    print('labelled points: {}'.format(np.sum([dflabel['cluster']==clust])))
    print('total points: {}'.format(np.sum(cl.labels_==clust)))
    print(dflabel[dflabel['cluster']==clust][['label', 'category']])
    print('\n\n\n')
# Out:
# cluster 0
# labelled points: 8
# total points: 32040
#             label  category
# 169  Poloniex_OMG  Exchange
# 170  Poloniex_OMG  Poloniex
# 173  Poloniex_GNT  Exchange
# 174  Poloniex_GNT  Poloniex
# 177  Poloniex_CVC  Exchange
# 178  Poloniex_CVC  Poloniex
# 179  Poloniex_REP  Exchange
# 180  Poloniex_REP  Poloniex
#
#
#
#
# cluster 1
# labelled points: 15
# total points: 19769
#                     label     category
# 1                 Bgogo_2     Exchange
# 11               Bitmax_2     Exchange
# 39              Gate.io_2     Exchange
# 49   MyEtherWallet_Donate       Donate
# 57             KuveraPool       Mining
# 68         CPChain_Wallet  ICO Wallets
# 85             BitUN.io_1     Exchange
# 91      LinkerCoin_Wallet  ICO Wallets
# 102        DMarket_Wallet  ICO Wallets
# 109  Compromised_Coindash  Compromised
# 110  Compromised_Coindash  ICO Wallets
# 129        Humaniq_Wallet  ICO Wallets
# 133    SingularDTV_Wallet  ICO Wallets
# 154  Substratum_TokenSale  ICO Wallets
# 155  Substratum_TokenSale   Token Sale
#
#
#
#
# cluster 2
# labelled points: 5
# total points: 30613
#           label  category
# 153       Upbit  Exchange
# 156  ShapeShift  Exchange
# 158  Poloniex_1  Exchange
# 159  Poloniex_1  Poloniex
# 168   Bittrex_1  Exchange
#
#
#
#
# cluster 3
# labelled points: 26
# total points: 16247
#                           label               category
# 6                 Rate3_Wallet2            ICO Wallets
# 15                Coinrail_Hack                  Heist
# 16                Coinrail_Hack             Phish/Hack
# 19            Fake_Phishing1431             Phish/Hack
# 29             Perlin_TokenSale             Token Sale
# 34              Airbloc_Wallet2            ICO Wallets
# 35                Rate3_Wallet1            ICO Wallets
# 48                Dether_Wallet            ICO Wallets
# 52          Lendingblock_Wallet            ICO Wallets
# 56                 Zebi_Wallet2            ICO Wallets
# 58         Fake_MetadiumPresale                  Heist
# 61             Trade.io_Wallet2            ICO Wallets
# 84               Atlant_Wallet2            ICO Wallets
# 86               Atlant_Wallet1            ICO Wallets
# 87             Copytrack_Wallet            ICO Wallets
# 90                BitJob_Wallet            ICO Wallets
# 93             Credits_MultiSig            ICO Wallets
# 95                  HOQU_Wallet            ICO Wallets
# 98              Tierion_Wallet2            ICO Wallets
# 100             Fake_Phishing74             Phish/Hack
# 107             Fake_Phishing30             Phish/Hack
# 121  BasicAttentionToken_Wallet  Basic Attention Token
# 122  BasicAttentionToken_Wallet            ICO Wallets
# 141              GatecoinHack_4                  Heist
# 163                Zebi_Wallet1            ICO Wallets
# 175           JordiBaylina(WHG)              White Hat
#
#
#
#
# cluster 4
# labelled points: 19
# total points: 15299
#                   label      category
# 2     Fake_Phishing2168    Phish/Hack
# 3     Fake_Phishing2172    Phish/Hack
# 4     Fake_Phishing1822    Phish/Hack
# 5     Fake_Phishing1816    Phish/Hack
# 7     Fake_Phishing1978    Phish/Hack
# 9              TheOcean  0x Ecosystem
# 10             TheOcean           Dex
# 12    Fake_Phishing1817    Phish/Hack
# 14    Fake_Phishing1952    Phish/Hack
# 17    Fake_Phishing1789    Phish/Hack
# 18    Fake_Phishing1624    Phish/Hack
# 21    Fake_Phishing1746    Phish/Hack
# 24    Fake_Phishing1236    Phish/Hack
# 27    Fake_Phishing1934    Phish/Hack
# 28    Fake_Phishing1133    Phish/Hack
# 33    Fake_Phishing1037    Phish/Hack
# 45     Fake_Phishing631    Phish/Hack
# 53     Fake_Phishing638    Phish/Hack
# 171  MelonFund_Deployer         Melon
#
#
#
#
# cluster 5
# labelled points: 26
# total points: 551
#                label      category
# 13          BigONE_1      Exchange
# 23             FCoin      Exchange
# 30          Huobi_15      Exchange
# 42         Gate.io_1      Exchange
# 43            Bilaxy      Exchange
# 55            Okex_1      Exchange
# 67          Remitano      Exchange
# 73            Hotbit      Exchange
# 79          HitBTC_3      Exchange
# 80            Coinex      Exchange
# 81       Cobinhood_1      Exchange
# 82        Bitfinex_4      Exchange
# 83          Coinbene      Exchange
# 88             Bibox      Exchange
# 96            Kucoin      Exchange
# 104        Binance_1       Binance
# 105        Binance_1      Exchange
# 113        Cryptopia      Exchange
# 114           Okex_2      Exchange
# 132       Liqui.io_1      Exchange
# 137  CoinExchange.io      Exchange
# 139         Gemini_1      Exchange
# 140         Gemini_1  Fiat Gateway
# 142        Changelly      Exchange
# 143       Freewallet    Wallet App
# 145  MiningPoolHub_1        Mining
#
#
#
#
# cluster 6
# labelled points: 21
# total points: 10802
#                           label      category
# 22            Fake_Phishing1605    Phish/Hack
# 32            Fake_Phishing2284    Phish/Hack
# 36                    StarBitEx  0x Ecosystem
# 37                    StarBitEx           Dex
# 38            Fake_Phishing1319    Phish/Hack
# 44             Fake_Phishing700    Phish/Hack
# 50            Fake_Phishing1722    Phish/Hack
# 54             Fake_Phishing429    Phish/Hack
# 60              MyCrypto_Donate        Donate
# 66        EuropeanCryptoBankICO    Token Sale
# 74             Fake_Phishing710    Phish/Hack
# 75                         DDEX  0x Ecosystem
# 76                         DDEX           Dex
# 92            Fake_Phishing2608    Phish/Hack
# 99              Fake_Phishing40    Phish/Hack
# 103            Etherscan_Donate        Donate
# 130             Fake_Phishing37    Phish/Hack
# 135            Ethplorer_Donate        Donate
# 164             NodePowerWallet   ICO Wallets
# 165  HadePlatformMultisigWallet   ICO Wallets
# 166           GronDigitalWallet   ICO Wallets
#
#
#
#
# cluster 7
# labelled points: 10
# total points: 32969
#              label  category
# 62   2Miners_PPLNS    Mining
# 101      SparkPool    Mining
# 106    Coinotron_3    Mining
# 112         FKPool    Mining
# 127  WaterholePool    Mining
# 134     Bitfinex_1  Exchange
# 146     Suprnova_2    Mining
# 147    DwarfPool_1    Mining
# 148      Ethpool_2    Mining
# 150       Nanopool    Mining
#
#
#
#
# cluster 8
# labelled points: 9
# total points: 17350
#          label  category
# 63   Binance_4   Binance
# 64   Binance_4  Exchange
# 65    HitBTC_2  Exchange
# 69   Binance_2   Binance
# 70   Binance_2  Exchange
# 71   Binance_3   Binance
# 72   Binance_3  Exchange
# 138   Kraken_4  Exchange
# 144  Ethermine    Mining
#
#
#
#
# cluster 9
# labelled points: 4
# total points: 16233
#         label  category
# 157  Kraken_1  Exchange
# 167   Yunbi_1  Exchange
# 176   Yunbi_2  Exchange
# 181  F2Pool_1    Mining
#
#
#
#
# cluster 10
# labelled points: 9
# total points: 27074
#                       label     category
# 31              INCX_Wallet  ICO Wallets
# 51              Hero_Wallet  ICO Wallets
# 89      Decentraland_Wallet  ICO Wallets
# 97           Monetha_Wallet  ICO Wallets
# 108       Santiment_Wallet2  ICO Wallets
# 111  MultisigExploit-Hacker        Heist
# 128       Santiment_Wallet1  ICO Wallets
# 136                Kraken_3     Exchange
# 160             DATx_Wallet  ICO Wallets
#
#
#
#
# cluster 11
# labelled points: 5
# total points: 2169
#           label  category
# 25    Gate.io_3  Exchange
# 41   Bitfinex_5  Exchange
# 77    Binance_5   Binance
# 78    Binance_5  Exchange
# 116     Huobi_6  Exchange
#
#
#
#
# cluster 12
# labelled points: 4
# total points: 1546
#          label  category
# 151    Huobi_8  Exchange
# 152   Mercatox  Exchange
# 161  Coindelta  Exchange
# 172   F2Pool_2    Mining
#
#
#
#
# cluster 13
# labelled points: 9
# total points: 7473
#               label     category
# 20           IDEX_2          Dex
# 59   WhalesburgPool       Mining
# 115        Huobi_11     Exchange
# 118        Huobi_10     Exchange
# 120         Huobi_2     Exchange
# 125        Huobi_12     Exchange
# 131      Liqui.io_2     Exchange
# 149       AlphaPool       Mining
# 162  SerenityWallet  ICO Wallets
#
#
#
#
# cluster 14
# labelled points: 12
# total points: 9495
#           label    category
# 0       Bgogo_1    Exchange
# 8      Bitmax_1    Exchange
# 26     Huobi_16    Exchange
# 40          Uex    Exchange
# 46   BitUN.io_2    Exchange
# 47         Cobo  Wallet App
# 94     BigONE_2    Exchange
# 117     Huobi_1    Exchange
# 119     Huobi_7    Exchange
# 123     Huobi_4    Exchange
# 124     Huobi_9    Exchange
# 126     Huobi_3    Exchange
